# %%
print(a)
# Out:
# 5

# %%
print("Someone name")
print(20,30,40,50)
print("Divyam")
print(23)
print("Ranchi,Jharkhand")
print("Apple",10,"Banana",30)
print(" ")


print("Name:","Divyam Raj")
print("Age:",23)
print("Gender:","Male")
print("Email:","divyamraj9431@gmail.com")
print("Year Of Graduation:",2024)
# Out:
# Someone name
# 20 30 40 50
# Divyam
# 23
# Ranchi,Jharkhand
# Apple 10 Banana 30
#
# Name: Divyam Raj
# Age: 23
# Gender: Male
# Email: divyamraj9431@gmail.com
# Year Of Graduation: 2024
